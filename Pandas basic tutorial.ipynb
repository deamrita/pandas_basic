# %%
import pandas as pd

# %% [markdown]
# ## Reading a data

# %%
df = pd.read_csv("C:/Users/Amrita/OneDrive/Desktop/pokeman.csv", header = 0)  
#*header = None* makes header as first row, 
#index_col healps us to specify a column as index, na_values to specify additional strings to recognize NAN
#Other important parameters are skipinitialspace = False, keep_default_na = True
#reading excel 
#df_1 = pd.read_excel("C:/Users/Amrita/OneDrive/Desktop/pokeman.xlsx")

#tab separated file
#df_2 = pd.read_csv("C:/Users/Amrita/OneDrive/Desktop/pokeman.txt", delimiter = '\t')

# %%
df.head(3)
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
df.tail(3)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
#read headers
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
#read a specific column
df.Name
df["Speed"][0:5]
df[["Name", "Type 1", "Type 2"]][0:5]
# Out:
#                     Name Type 1  Type 2
# 0              Bulbasaur  Grass  Poison
# 1                Ivysaur  Grass  Poison
# 2               Venusaur  Grass  Poison
# 3  VenusaurMega Venusaur  Grass  Poison
# 4             Charmander   Fire     NaN

# %%
#read a specific rows
df.iloc[0:5]
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#read a specific location
df.iloc[2,1] #row index, column index
df.loc[2,"Name"] #row index, column name
# Out:
# 'Venusaur'

# %% [markdown]
# ## Describing data

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# ## Sorting df

# %%
df.sort_values("Name", ascending = False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(["Name","HP"], ascending = [False,True])
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## Making changes to the data

# %%
#adding columns
#df["Total"] = df["HP"]+df["Attack"]+df["Defense"]+df["Speed"]
#df = df.drop(columns = "Total")
df["Total"] = df.iloc[:,3:6].sum(axis = 1) #loc is not working

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False     94
# 1       80     60           1      False    122
# 2      100     80           1      False    162
# 3      120     80           1      False    180
# 4       50     65           1      False     91

# %%
#dropping a columne
df = df.drop(columns = "#")

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison  45      49       49       65
# 1                Ivysaur  Grass  Poison  60      62       63       80
# 2               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False     94
# 1       80     60           1      False    122
# 2      100     80           1      False    162
# 3      120     80           1      False    180
# 4       50     65           1      False     91

# %%
#rearranging columns

# %%
cols = list(df.columns.values)

# %%
cols
# Out:
# ['Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary',
#  'Total']

# %%
df = df[cols[0:3] + [cols[-1]] + cols[3:11]]

# %%
df
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison     94  45      49       49
# 1                  Ivysaur    Grass  Poison    122  60      62       63
# 2                 Venusaur    Grass  Poison    162  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    180  80     100      123
# 4               Charmander     Fire     NaN     91  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    150  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    210  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    190  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    240  80     160       60
# 799              Volcanion     Fire   Water    190  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## Filtering data

# %%
filter1 = (df["Type 1"] == "Grass")
df.loc[filter1,:] #iloc is not applicable
# Out:
#                       Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 0                Bulbasaur  Grass    Poison     94   45      49       49
# 1                  Ivysaur  Grass    Poison    122   60      62       63
# 2                 Venusaur  Grass    Poison    162   80      82       83
# 3    VenusaurMega Venusaur  Grass    Poison    180   80     100      123
# 48                  Oddish  Grass    Poison     95   45      50       55
# ..                     ...    ...       ...    ...  ...     ...      ...
# 718                Chespin  Grass       NaN    117   56      61       65
# 719              Quilladin  Grass       NaN    139   61      78       95
# 720             Chesnaught  Grass  Fighting    195   88     107      122
# 740                 Skiddo  Grass       NaN    131   66      65       48
# 741                 Gogoat  Grass       NaN    223  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
filter2 = (df["Type 1"] == "Grass") & (df["Type 2"] == "Poison")
df.loc[filter2,:] #iloc is not applicable
# Out:
#                       Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 0                Bulbasaur  Grass  Poison     94   45      49       49
# 1                  Ivysaur  Grass  Poison    122   60      62       63
# 2                 Venusaur  Grass  Poison    162   80      82       83
# 3    VenusaurMega Venusaur  Grass  Poison    180   80     100      123
# 48                  Oddish  Grass  Poison     95   45      50       55
# 49                   Gloom  Grass  Poison    125   60      65       70
# 50               Vileplume  Grass  Poison    155   75      80       85
# 75              Bellsprout  Grass  Poison    125   50      75       35
# 76              Weepinbell  Grass  Poison    155   65      90       50
# 77              Victreebel  Grass  Poison    185   80     105       65
# 344                Roselia  Grass  Poison    110   50      60       45
# 451                  Budew  Grass  Poison     70   40      30       35
# ...

# %%
filter3 = (df["Type 1"] == "Grass") & (df["Type 2"] == "Poison") & (df["HP"] > 70)
new_df = df.loc[filter3,:] #iloc is not applicable

# %%
#reseting index 
new_df.reset_index(drop = True,inplace = True)

# %%
new_df
# Out:
#                     Name Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0               Venusaur  Grass  Poison    162   80      82       83      100
# 1  VenusaurMega Venusaur  Grass  Poison    180   80     100      123      122
# 2              Vileplume  Grass  Poison    155   75      80       85      110
# 3             Victreebel  Grass  Poison    185   80     105       65      100
# 4              Amoonguss  Grass  Poison    199  114      85       70       85
#
#    Sp. Def  Speed  Generation  Legendary
# 0      100     80           1      False
# 1      120     80           1      False
# 2       90     50           1      False
# 3       70     70           1      False
# 4       80     30           5      False

# %%
filter4 = df["Name"].str.contains("Mega")
df[filter4]
# Out:
#                           Name    Type 1    Type 2  Total   HP  Attack  \
# 3        VenusaurMega Venusaur     Grass    Poison    180   80     100
# 7    CharizardMega Charizard X      Fire    Dragon    208   78     130
# 8    CharizardMega Charizard Y      Fire    Flying    182   78     104
# 12     BlastoiseMega Blastoise     Water       NaN    182   79     103
# 19       BeedrillMega Beedrill       Bug    Poison    215   65     150
# 23         PidgeotMega Pidgeot    Normal    Flying    163   83      80
# 71       AlakazamMega Alakazam   Psychic       NaN    105   55      50
# 87         SlowbroMega Slowbro     Water   Psychic    170   95      75
# 102          GengarMega Gengar     Ghost    Poison    125   60      65
# 124  KangaskhanMega Kangaskhan    Normal       NaN    230  105     125
# 137          PinsirMega Pinsir       Bug    Flying    220   65     155
# 141      GyaradosMega Gyarados     Water      Dark    250   95     155
# ...

# %%
filter4 = (df["Name"].str.contains("Mega"))
df[~filter4] # to discard filtered things
# Out:
#                     Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0              Bulbasaur    Grass  Poison     94   45      49       49
# 1                Ivysaur    Grass  Poison    122   60      62       63
# 2               Venusaur    Grass  Poison    162   80      82       83
# 4             Charmander     Fire     NaN     91   39      52       43
# 5             Charmeleon     Fire     NaN    122   58      64       58
# ..                   ...      ...     ...    ...  ...     ...      ...
# 794     Zygarde50% Forme   Dragon  Ground    208  108     100      121
# 795              Diancie     Rock   Fairy    150   50     100      150
# 797  HoopaHoopa Confined  Psychic   Ghost    190   80     110       60
# 798   HoopaHoopa Unbound  Psychic    Dark    240   80     160       60
# 799            Volcanion     Fire   Water    190   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
import re

filter5 = df["Name"].str.contains('^pi[a-z]*', flags = re.I, regex = True) #^ specify start of the line
df[filter5]
# Out:
#                     Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 20                Pidgey    Normal    Flying     85   40      45       40
# 21             Pidgeotto    Normal    Flying    123   63      60       55
# 22               Pidgeot    Normal    Flying    163   83      80       75
# 23   PidgeotMega Pidgeot    Normal    Flying    163   83      80       80
# 30               Pikachu  Electric       NaN     90   35      55       40
# 136               Pinsir       Bug       NaN    190   65     125      100
# 137    PinsirMega Pinsir       Bug    Flying    220   65     155      120
# 186                Pichu  Electric       NaN     60   20      40       15
# 219               Pineco       Bug       NaN    115   50      65       90
# 239            Piloswine       Ice    Ground    200  100     100       80
# 438               Piplup     Water       NaN    104   53      51       53
# 558              Pignite      Fire  Fighting    183   90      93       55
# ...

# %% [markdown]
# ## Conditional changes

# %%
filter6 = df["Type 1"] == "Fire"

#df.loc[filter6,"Type 1"] = "Flame"

filter7 = df["Type 1"] == "Flame"
df.loc[filter7,["Generation","Legendary"]] = ["tv1","tv2"]
df
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison     94  45      49       49
# 1                  Ivysaur    Grass  Poison    122  60      62       63
# 2                 Venusaur    Grass  Poison    162  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    180  80     100      123
# 4               Charmander    Flame     NaN     91  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    150  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    210  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    190  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    240  80     160       60
# 799              Volcanion    Flame   Water    190  80     110      120
#
#      Sp. Atk  Sp. Def  Speed Generation Legendary
# 0         65       65     45          1     False
# ...

# %% [markdown]
# ## Group by

# %%
df.groupby("Type 1").mean().sort_values("Defense", ascending = False)
# Out:
#                Total         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Steel     157.925926  65.222222   92.703704  126.370370  67.518519  80.629630
# Rock      158.227273  65.363636   92.863636  100.795455  63.340909  75.477273
# Dragon    195.437500  83.312500  112.125000   86.375000  96.843750  88.843750
# Ground    169.531250  73.781250   95.750000   84.843750  56.468750  62.750000
# Ghost     138.218750  64.437500   73.781250   81.187500  79.343750  76.468750
# Water     146.214286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice       144.750000  72.000000   72.750000   71.416667  77.541667  76.291667
# Grass     140.485714  67.271429   73.214286   70.800000  77.500000  70.428571
# Bug       127.855072  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      155.193548  66.806452   88.387097   70.225806  74.645161  69.516129
# Poison    141.928571  67.250000   74.678571   68.821429  60.428571  64.392857
# ...

# %%
df_new = df.groupby("Type 1")["HP"].mean().reset_index()

# %%
df_new
# Out:
#       Type 1         HP
# 0        Bug  56.884058
# 1       Dark  66.806452
# 2     Dragon  83.312500
# 3   Electric  59.795455
# 4      Fairy  74.117647
# 5   Fighting  69.851852
# 6      Flame  69.903846
# 7     Flying  70.750000
# 8      Ghost  64.437500
# 9      Grass  67.271429
# 10    Ground  73.781250
# 11       Ice  72.000000
# 12    Normal  77.275510
# 13    Poison  67.250000
# 14   Psychic  70.631579
# 15      Rock  65.363636
# 16     Steel  65.222222
# 17     Water  72.062500

# %% [markdown]
# ## Exporting to csv

# %%
df.to_csv("C:/Users/Amrita/OneDrive/Desktop/pokeman.csv", index = False)
